# %% [markdown]
# <a href="https://colab.research.google.com/github/asadstat/Data_analysis/blob/master/03_03_2022_Sentiment_n_words_and_n_contentwords.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Analysis for n_words

# %% [markdown]
# ##Installing necessary packages

# %%
install.packages(c("ggplot2","reshape2","gridExtra"))
# Out:
# Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘plyr’

# %% [markdown]
# # Creating data frame and Boxplot for n_words: For each condition considering all languages with Emotions

# %%
library(ggplot2)
library(reshape2)
library(gridExtra)
d <- read.csv("ou2.csv",header=T)
d <- d[c(1:2,11,14:21)]
d1 <- d[4:11]/(d$n_words)
dt <- data.frame(d[c(1:2)],d1)
dt <- na.omit(dt)
attach(dt)
dt$condition 
dt1 <-dt[dt$condition =='1 Mal di schiena',]
df1 <- dt1[-1]
long <- melt(df1)
names(long)[2:3] <- c("Emotion_Word","Value")
attach(long)
options(repr.plot.width = 18, repr.plot.height =75)
p1 <- ggplot(long, aes(x=Emotion_Word , y=Value, fill=language))+ 
    geom_boxplot()+facet_grid(~language)+theme(legend.position="none")
p1 <- p1+ggtitle("1 Mal di schiena")+theme(plot.title = element_text(hjust =.5))
p1 <- p1 + theme(text = element_text(size=22),
      axis.text.x = element_text(angle=90, hjust=1))
p1 <- p1+theme(legend.position = "none")


dt2 <-dt[dt$condition =='2 Ernia del disco',]
df2 <- dt2[-1]
long2 <- melt(df2)
names(long2)[2:3] <- c("Emotion_Word","Value")
attach(long2)
options(repr.plot.width = 18, repr.plot.height =75)
p2 <- ggplot(long2, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
##### if  you change the plot theme then run the below line otherwise ignore
#p1<-p1+theme_classic()+theme(plot.title = element_text(hjust = 0.5))
p2 <- p2+ggtitle("2 Ernia del disco")+theme(plot.title = element_text(hjust =0.5))
p2 <-p2 + theme(text = element_text(size=22),
      axis.text.x = element_text(angle=90, hjust=1))
p2 <- p2+theme(legend.position = "none")


dt3 <-dt[dt$condition =='3 Chirugia vertebrale',]
df3 <- dt3[-1]
long3 <- melt(df2)
names(long3)[2:3] <- c("Emotion_Word","Value")
attach(long3)
options(repr.plot.width = 18, repr.plot.height =75)
p3 <- ggplot(long3, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p3 <- p3+ggtitle("3 Chirugia vertebrale")+theme(plot.title = element_text(hjust =0.5))
p3 <-p3 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p3 <- p3+theme(legend.position = "none")

dt4 <-dt[dt$condition =='4 Protesi anca',]
df4 <- dt4[-1]
long4 <- melt(df4)
names(long4)[2:3] <- c("Emotion_Word","Value")
attach(long4)
options(repr.plot.width = 18, repr.plot.height =75)
p4 <- ggplot(long4, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p4 <- p4+ggtitle("4 Protesi anca")+theme(plot.title = element_text(hjust =0.5))
p4 <- p4 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p4 <- p4+theme(legend.position = "none")

dt5 <-dt[dt$condition =='5 Artrosi anca',]
df5 <- dt5[-1]
long5 <- melt(df5)
names(long5)[2:3] <- c("Emotion_Word","Value")
attach(long5)
options(repr.plot.width = 18, repr.plot.height =75)
p5 <- ggplot(long5, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p5 <- p5+ggtitle("5 Artrosi anca")+theme(plot.title = element_text(hjust =0.5))
p5 <- p5 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p5 <- p5+theme(legend.position = "none")

dt6 <-dt[dt$condition =='6 Protesi ginocchio',]
df6 <- dt6[-1]
long6 <- melt(df6)
names(long6)[2:3] <- c("Emotion_Word","Value")
attach(long6)
options(repr.plot.width = 18, repr.plot.height =75)
p6 <- ggplot(long6, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p6 <- p6+ggtitle("6 Protesi ginocchio")+theme(plot.title = element_text(hjust =0.5))
p6 <- p6 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p6 <- p6+theme(legend.position = "none")

dt7 <-dt[dt$condition =='7 Artrosi ginocchio',]
df7 <- dt7[-1]
long7 <- melt(df7)
names(long7)[2:3] <- c("Emotion_Word","Value")
attach(long7)
options(repr.plot.width = 18, repr.plot.height =75)
p7 <- ggplot(long7, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p7 <- p7+ggtitle("7 Artrosi ginocchio")+theme(plot.title = element_text(hjust =0.5))
p7 <- p7 +theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p7 <- p7+theme(legend.position = "none")

dt8 <-dt[dt$condition =='8 Dolore cervicale',]
df8 <- dt8[-1]
long8 <- melt(df8)
names(long8)[2:3] <- c("Emotion_Word","Value")
attach(long8)
options(repr.plot.width = 18, repr.plot.height =75)
p8 <- ggplot(long8, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p8 <- p8+ggtitle("8 Dolore cervicale")+theme(plot.title = element_text(hjust =0.5))
p8 <- p8 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p8 <- p8+theme(legend.position = "none")

dt9 <-dt[dt$condition =='9 Lombalgia',]
df9 <- dt9[-1]
long9 <- melt(df9)
names(long9)[2:3] <- c("Emotion_Word","Value")
attach(long9)
options(repr.plot.width = 18, repr.plot.height =75)
p9 <- ggplot(long9, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p9 <- p9+ggtitle("9 Lombalgia")+theme(plot.title = element_text(hjust =0.5))
p9 <- p9 +theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p9 <- p9+theme(legend.position = "none")
grid.arrange(p1, p2,p3,p4,p5,p6,p7,p8,p9, ncol=1)

# %% [markdown]
# # Creating data frame and Boxplot for n_words: For each language considering all conditions with Emotions

# %%
library(ggplot2)
library(reshape2)
library(gridExtra)
d <- read.csv("ou2.csv",header=T)
d <- d[c(1:2,11,14:21)]
d1 <- d[4:11]/(d$n_words)
dt <- data.frame(d[c(1:2)],d1)
dt <- na.omit(dt)
attach(dt)
dt$language 
dt1 <-dt[dt$language =='de',]
df1 <- dt1[-2]
long <- melt(df1)
names(long)[2:3] <- c("Emotion_Word","Value")
attach(long)
options(repr.plot.width = 25, repr.plot.height =50)
p1 <- ggplot(long, aes(x=Emotion_Word , y=Value, fill=condition))+ 
    geom_boxplot()+facet_grid(~condition)+theme(legend.position="none")
p1 <- p1+ggtitle("de")+theme(plot.title = element_text(hjust =.5))
p1 <- p1 + theme(text = element_text(size=22),
      axis.text.x = element_text(angle=90, hjust=1))
p1 <- p1+theme(legend.position = "none")


dt2 <-dt[dt$language =='en',]
df2 <- dt2[-2]
long2 <- melt(df2)
names(long2)[2:3] <- c("Emotion_Word","Value")
attach(long2)
options(repr.plot.width = 25, repr.plot.height =50)
p2 <- ggplot(long2, aes(x=Emotion_Word , y=Value, fill=condition)) + 
    geom_boxplot()+facet_grid(~condition)
##### if  you change the plot theme then run the below line otherwise ignore
#p1<-p1+theme_classic()+theme(plot.title = element_text(hjust = 0.5))
p2 <- p2+ggtitle("en")+theme(plot.title = element_text(hjust =0.5))
p2 <-p2 + theme(text = element_text(size=22),
      axis.text.x = element_text(angle=90, hjust=1))
p2 <- p2+theme(legend.position = "none")


dt3 <-dt[dt$language =='es',]
df3 <- dt3[-2]
long3 <- melt(df2)
names(long3)[2:3] <- c("Emotion_Word","Value")
attach(long3)
options(repr.plot.width = 25, repr.plot.height =50)
p3 <- ggplot(long3, aes(x=Emotion_Word , y=Value, fill=condition)) + 
    geom_boxplot()+facet_grid(~condition)
p3 <- p3+ggtitle("es")+theme(plot.title = element_text(hjust =0.5))
p3 <-p3 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p3 <- p3+theme(legend.position = "none")

dt4 <-dt[dt$language =='fr',]
df4 <- dt4[-2]
long4 <- melt(df4)
names(long4)[2:3] <- c("Emotion_Word","Value")
attach(long4)
options(repr.plot.width = 25, repr.plot.height =50)
p4 <- ggplot(long4, aes(x=Emotion_Word , y=Value, fill=condition)) + 
    geom_boxplot()+facet_grid(~condition)
p4 <- p4+ggtitle("fr")+theme(plot.title = element_text(hjust =0.5))
p4 <- p4 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p4 <- p4+theme(legend.position = "none")

dt5 <-dt[dt$language =='it',]
df5 <- dt5[-2]
long5 <- melt(df5)
names(long5)[2:3] <- c("Emotion_Word","Value")
attach(long5)
options(repr.plot.width = 25, repr.plot.height =50)
p5 <- ggplot(long5, aes(x=Emotion_Word , y=Value, fill=condition)) + 
    geom_boxplot()+facet_grid(~condition)
p5 <- p5+ggtitle("it")+theme(plot.title = element_text(hjust =0.5))
p5 <- p5 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p5 <- p5+theme(legend.position = "none")

grid.arrange(p1,p2,p3,p4,p5,ncol=1)

# %% [markdown]
# # Analysis for n_content words

# %% [markdown]
# # Creating data frame and boxplot for n_content words: For each condition considering all language with emotions

# %%
library(ggplot2)
library(reshape2)
library(gridExtra)
d <- read.csv("ou2.csv",header=T)
d <- d[c(1:2,12,14:21)]
d1 <- d[4:11]/(d$n_contentwords)
dt <- data.frame(d[c(1:2)],d1)
dt <- na.omit(dt)
attach(dt)
dt$condition 
dt1 <-dt[dt$condition =='1 Mal di schiena',]
df1 <- dt1[-1]
long <- melt(df1)
names(long)[2:3] <- c("Emotion_Word","Value")
attach(long)
options(repr.plot.width = 18, repr.plot.height =75)
p1 <- ggplot(long, aes(x=Emotion_Word , y=Value, fill=language))+ 
    geom_boxplot()+facet_grid(~language)+theme(legend.position="none")
p1 <- p1+ggtitle("1 Mal di schiena")+theme(plot.title = element_text(hjust =.5))
p1 <- p1 + theme(text = element_text(size=22),
      axis.text.x = element_text(angle=90, hjust=1))
p1 <- p1+theme(legend.position = "none")


dt2 <-dt[dt$condition =='2 Ernia del disco',]
df2 <- dt2[-1]
long2 <- melt(df2)
names(long2)[2:3] <- c("Emotion_Word","Value")
attach(long2)
options(repr.plot.width = 18, repr.plot.height =75)
p2 <- ggplot(long2, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
##### if  you change the plot theme then run the below line otherwise ignore
#p1<-p1+theme_classic()+theme(plot.title = element_text(hjust = 0.5))
p2 <- p2+ggtitle("2 Ernia del disco")+theme(plot.title = element_text(hjust =0.5))
p2 <-p2 + theme(text = element_text(size=22),
      axis.text.x = element_text(angle=90, hjust=1))
p2 <- p2+theme(legend.position = "none")


dt3 <-dt[dt$condition =='3 Chirugia vertebrale',]
df3 <- dt3[-1]
long3 <- melt(df2)
names(long3)[2:3] <- c("Emotion_Word","Value")
attach(long3)
options(repr.plot.width = 18, repr.plot.height =75)
p3 <- ggplot(long3, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p3 <- p3+ggtitle("3 Chirugia vertebrale")+theme(plot.title = element_text(hjust =0.5))
p3 <-p3 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p3 <- p3+theme(legend.position = "none")

dt4 <-dt[dt$condition =='4 Protesi anca',]
df4 <- dt4[-1]
long4 <- melt(df4)
names(long4)[2:3] <- c("Emotion_Word","Value")
attach(long4)
options(repr.plot.width = 18, repr.plot.height =75)
p4 <- ggplot(long4, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p4 <- p4+ggtitle("4 Protesi anca")+theme(plot.title = element_text(hjust =0.5))
p4 <- p4 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p4 <- p4+theme(legend.position = "none")

dt5 <-dt[dt$condition =='5 Artrosi anca',]
df5 <- dt5[-1]
long5 <- melt(df5)
names(long5)[2:3] <- c("Emotion_Word","Value")
attach(long5)
options(repr.plot.width = 18, repr.plot.height =75)
p5 <- ggplot(long5, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p5 <- p5+ggtitle("5 Artrosi anca")+theme(plot.title = element_text(hjust =0.5))
p5 <- p5 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p5 <- p5+theme(legend.position = "none")

dt6 <-dt[dt$condition =='6 Protesi ginocchio',]
df6 <- dt6[-1]
long6 <- melt(df6)
names(long6)[2:3] <- c("Emotion_Word","Value")
attach(long6)
options(repr.plot.width = 18, repr.plot.height =75)
p6 <- ggplot(long6, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p6 <- p6+ggtitle("6 Protesi ginocchio")+theme(plot.title = element_text(hjust =0.5))
p6 <- p6 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p6 <- p6+theme(legend.position = "none")

dt7 <-dt[dt$condition =='7 Artrosi ginocchio',]
df7 <- dt7[-1]
long7 <- melt(df7)
names(long7)[2:3] <- c("Emotion_Word","Value")
attach(long7)
options(repr.plot.width = 18, repr.plot.height =75)
p7 <- ggplot(long7, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p7 <- p7+ggtitle("7 Artrosi ginocchio")+theme(plot.title = element_text(hjust =0.5))
p7 <- p7 +theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p7 <- p7+theme(legend.position = "none")

dt8 <-dt[dt$condition =='8 Dolore cervicale',]
df8 <- dt8[-1]
long8 <- melt(df8)
names(long8)[2:3] <- c("Emotion_Word","Value")
attach(long8)
options(repr.plot.width = 18, repr.plot.height =75)
p8 <- ggplot(long8, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p8 <- p8+ggtitle("8 Dolore cervicale")+theme(plot.title = element_text(hjust =0.5))
p8 <- p8 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p8 <- p8+theme(legend.position = "none")

dt9 <-dt[dt$condition =='9 Lombalgia',]
df9 <- dt9[-1]
long9 <- melt(df9)
names(long9)[2:3] <- c("Emotion_Word","Value")
attach(long9)
options(repr.plot.width = 18, repr.plot.height =75)
p9 <- ggplot(long9, aes(x=Emotion_Word , y=Value, fill=language)) + 
    geom_boxplot()+facet_grid(~language)
p9 <- p9+ggtitle("9 Lombalgia")+theme(plot.title = element_text(hjust =0.5))
p9 <- p9 +theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p9 <- p9+theme(legend.position = "none")
grid.arrange(p1, p2,p3,p4,p5,p6,p7,p8,p9, ncol=1)
# Out:
# The following object is masked from long5 (pos = 3):
#
#     condition
#
#
# The following object is masked from long4 (pos = 4):
#
#     condition
#
#
# The following object is masked from long3 (pos = 5):
#
#     condition
#
#
# The following object is masked from long2 (pos = 6):
#
#     condition
#
#
# The following object is masked from long (pos = 7):
#
#     condition
#
#
# The following objects are masked from dt (pos = 8):
#
#     admiration, anger, condition, disgust, fear, interest, joy,
#     language, sadness, surprise
#
#
# The following object is masked from long9 (pos = 9):
#
#     language
#
#
# The following object is masked from long8 (pos = 10):
#
#     language
#
#
# The following object is masked from long7 (pos = 11):
#
#     language
#
#
# The following object is masked from long6 (pos = 12):
#
#     language
#
#
# The following object is masked from long5 (pos = 13):
#
#     language
#
#
# The following object is masked from long4 (pos = 14):
#
# ...

# %% [markdown]
# # Creating data frame and Boxplot for n_content words: For each condition considering all languages with Emotions

# %%
library(ggplot2)
library(reshape2)
library(gridExtra)
d <- read.csv("ou2.csv",header=T)
d <- d[c(1:2,12,14:21)]
d1 <- d[4:11]/(d$n_contentwords)
dt <- data.frame(d[c(1:2)],d1)
dt <- na.omit(dt)
attach(dt)
dt$language 
dt1 <-dt[dt$language =='de',]
df1 <- dt1[-2]
long <- melt(df1)
names(long)[2:3] <- c("Emotion_Word","Value")
attach(long)
options(repr.plot.width = 25, repr.plot.height =50)
p1 <- ggplot(long, aes(x=Emotion_Word , y=Value, fill=condition))+ 
    geom_boxplot()+facet_grid(~condition)+theme(legend.position="none")
p1 <- p1+ggtitle("de")+theme(plot.title = element_text(hjust =.5))
p1 <- p1 + theme(text = element_text(size=22),
      axis.text.x = element_text(angle=90, hjust=1))
p1 <- p1+theme(legend.position = "none")


dt2 <-dt[dt$language =='en',]
df2 <- dt2[-2]
long2 <- melt(df2)
names(long2)[2:3] <- c("Emotion_Word","Value")
attach(long2)
options(repr.plot.width = 25, repr.plot.height =50)
p2 <- ggplot(long2, aes(x=Emotion_Word , y=Value, fill=condition)) + 
    geom_boxplot()+facet_grid(~condition)
##### if  you change the plot theme then run the below line otherwise ignore
#p1<-p1+theme_classic()+theme(plot.title = element_text(hjust = 0.5))
p2 <- p2+ggtitle("en")+theme(plot.title = element_text(hjust =0.5))
p2 <-p2 + theme(text = element_text(size=22),
      axis.text.x = element_text(angle=90, hjust=1))
p2 <- p2+theme(legend.position = "none")


dt3 <-dt[dt$language =='es',]
df3 <- dt3[-2]
long3 <- melt(df2)
names(long3)[2:3] <- c("Emotion_Word","Value")
attach(long3)
options(repr.plot.width = 25, repr.plot.height =50)
p3 <- ggplot(long3, aes(x=Emotion_Word , y=Value, fill=condition)) + 
    geom_boxplot()+facet_grid(~condition)
p3 <- p3+ggtitle("es")+theme(plot.title = element_text(hjust =0.5))
p3 <-p3 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p3 <- p3+theme(legend.position = "none")

dt4 <-dt[dt$language =='fr',]
df4 <- dt4[-2]
long4 <- melt(df4)
names(long4)[2:3] <- c("Emotion_Word","Value")
attach(long4)
options(repr.plot.width = 25, repr.plot.height =50)
p4 <- ggplot(long4, aes(x=Emotion_Word , y=Value, fill=condition)) + 
    geom_boxplot()+facet_grid(~condition)
p4 <- p4+ggtitle("fr")+theme(plot.title = element_text(hjust =0.5))
p4 <- p4 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p4 <- p4+theme(legend.position = "none")

dt5 <-dt[dt$language =='it',]
df5 <- dt5[-2]
long5 <- melt(df5)
names(long5)[2:3] <- c("Emotion_Word","Value")
attach(long5)
options(repr.plot.width = 25, repr.plot.height =50)
p5 <- ggplot(long5, aes(x=Emotion_Word , y=Value, fill=condition)) + 
    geom_boxplot()+facet_grid(~condition)
p5 <- p5+ggtitle("it")+theme(plot.title = element_text(hjust =0.5))
p5 <- p5 + theme(text = element_text(size=22), axis.text.x = element_text(angle=90, hjust=1))
p5 <- p5+theme(legend.position = "none")

grid.arrange(p1,p2,p3,p4,p5,ncol=1)
# Out:
# The following object is masked from long9 (pos = 3):
#
#     language
#
#
# The following object is masked from long8 (pos = 4):
#
#     language
#
#
# The following object is masked from long7 (pos = 5):
#
#     language
#
#
# The following object is masked from long6 (pos = 6):
#
#     language
#
#
# The following object is masked from long5 (pos = 7):
#
#     language
#
#
# The following object is masked from long4 (pos = 8):
#
#     language
#
#
# The following object is masked from long3 (pos = 9):
#
#     language
#
#
# The following object is masked from long2 (pos = 10):
#
#     language
#
#
# The following object is masked from long (pos = 11):
#
#     language
#
#
# The following objects are masked from dt (pos = 12):
#
#     admiration, anger, condition, disgust, fear, interest, joy,
#     language, sadness, surprise
#
#
# The following object is masked from long5 (pos = 13):
#
#     condition
#
#
# The following object is masked from long4 (pos = 14):
#
#     condition
#
# ...
